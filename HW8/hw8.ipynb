# %% [markdown]
# <a href="https://colab.research.google.com/github/montimaj/Deep-Learning-SE-6213/blob/master/HW8/hw8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SYS ENG 6213 - Deep Learning and Advanced Neural Networks

# %% [markdown]
# ### Homework#5: RNN and LSTM networks

# %% [markdown]
# In this homework, you will be implementing the RNN and LSTM networks on Penn Treebank dataset. These architectures are useful for data which have dependencies like sequences and lists. For example, Language modelling where the future words in text are predicted based on history of previous words.
#
# Few more applications:
# 1. Speech recognition
# 2. Language modeling
# 3. Translation
# 4. Image captioning
#
# Detailed information on RNN and LSTM can be found @ http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd 'drive/My Drive/SysEng 6213 Fall 2020 Sayantan Majumdar /HW8'
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1xpWpUfn0NqGtbgAP_303jr6QW5RKzJPR/SysEng 6213 Fall 2020 Sayantan Majumdar /HW8
# data	   layers.py	 reader.py	rnn_pic.png  utilities.py
# hw8.ipynb  lstm_pic.png  rnn_layers.py	rnn.py

# %%
# !pip install tensorflow
import os
import pickle as pickle
import reader
import tensorflow as tf
import numpy as np
from rnn_layers import *
from utilities import _get_batch,_divide_into_batches
from rnn import *
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.33.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow) (50.3.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.17.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (2.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (3.3.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)

# %% [markdown]
# __Dataset:__
#
# For this homework, we will use the [Penn Tree Bank](https://catalog.ldc.upenn.edu/ldc99t42) (PTB) dataset, which is a popular benchmark for measuring the quality of these models, whilst being small and relatively fast to train. Below is a small sample of data.

# %%
with tf.io.gfile.GFile(os.path.join(os.getcwd(),'data', "ptb.train.txt"), "r") as f:
    data = f.read()
data[0:2000]
# Out:
# " aer banknote berlitz calloway centrust cluett fromstein gitano guterman hydro-quebec ipo kia memotec mlx nahb punts rake regatta rubens sim snack-food ssangyong swapo wachter \n pierre <unk> N years old will join the board as a nonexecutive director nov. N \n mr. <unk> is chairman of <unk> n.v. the dutch publishing group \n rudolph <unk> N years old and former chairman of consolidated gold fields plc was named a nonexecutive director of this british industrial conglomerate \n a form of asbestos once used to make kent cigarette filters has caused a high percentage of cancer deaths among a group of workers exposed to it more than N years ago researchers reported \n the asbestos fiber <unk> is unusually <unk> once it enters the <unk> with even brief exposures to it causing symptoms that show up decades later researchers said \n <unk> inc. the unit of new york-based <unk> corp. that makes kent cigarettes stopped using <unk> in its <unk> cigarette filters in N \n although preliminary findings were reported more than a year ago the latest results appear in today 's new england journal of medicine a forum likely to bring new attention to the problem \n a <unk> <unk> said this is an old story \n we 're talking about years ago before anyone heard of asbestos having any questionable properties \n there is no asbestos in our products now \n neither <unk> nor the researchers who studied the workers were aware of any research on smokers of the kent cigarettes \n we have no useful information on whether users are at risk said james a. <unk> of boston 's <unk> cancer institute \n dr. <unk> led a team of researchers from the national cancer institute and the medical schools of harvard university and boston university \n the <unk> spokeswoman said asbestos was used in very modest amounts in making paper for the filters in the early 1950s and replaced with a different type of <unk> in N \n from N to N N billion kent cigarettes with the filters were sold the company said \n among N men who worked cl"

# %% [markdown]
# __Pre Processing__
#
# The given dataset is a collection of words as shown above. In order to train an neural network we need numerical representation of the data. For this purpose, we encode each word in the dataset with unique numerical values. The following code implements the conversion of dataset words into numerical values.

# %%
data_path = os.path.join(os.getcwd(),'data')
raw_data = reader.ptb_raw_data(data_path)
train_data, valid_data, test_data, vocabulary, word_ids = raw_data
data = {'train_data':train_data[0:10000],'valid_data':valid_data,'test_data':test_data,'vocabulary':vocabulary,'word_ids':word_ids}
ids_words = {i: w for w, i in word_ids.items()}

# %%
word_ids
# Out:
# {'the': 0,
#  '<unk>': 1,
#  '<eos>': 2,
#  'N': 3,
#  'of': 4,
#  'to': 5,
#  'a': 6,
#  'in': 7,
#  'and': 8,
#  "'s": 9,
#  'that': 10,
#  'for': 11,
#  '$': 12,
#  'is': 13,
#  'it': 14,
#  'said': 15,
#  'on': 16,
#  'by': 17,
#  'at': 18,
#  'as': 19,
#  'from': 20,
#  'million': 21,
#  'with': 22,
#  'mr.': 23,
#  'was': 24,
#  'be': 25,
#  'are': 26,
#  'its': 27,
#  'he': 28,
#  'but': 29,
#  'has': 30,
#  'an': 31,
#  "n't": 32,
#  'will': 33,
#  'have': 34,
#  'new': 35,
#  'or': 36,
#  'company': 37,
#  'they': 38,
#  'this': 39,
#  'year': 40,
#  'which': 41,
#  'would': 42,
#  'about': 43,
#  'says': 44,
#  'more': 45,
#  'were': 46,
#  'market': 47,
#  'billion': 48,
#  'his': 49,
#  'had': 50,
#  'their': 51,
#  'up': 52,
#  'u.s.': 53,
#  'one': 54,
#  'than': 55,
#  'who': 56,
#  'some': 57,
#  'been': 58,
#  'also': 59,
#  'stock': 60,
#  'other': 61,
#  'share': 62,
#  'not': 63,
#  'we': 64,
#  'corp.': 65,
#  'if': 66,
#  'when': 67,
#  'i': 68,
#  'last': 69,
#  'president': 70,
#  'shares': 71,
#  'years': 72,
#  'all': 73,
#  'first': 74,
#  'two': 75,
#  'because': 76,
#  'trading': 77,
#  'after': 78,
#  'could': 79,
#  'inc.': 80,
#  'sales': 81,
#  '&': 82,
#  'there': 83,
#  'out': 84,
#  'business': 85,
#  'only': 86,
#  'do': 87,
#  'such': 88,
#  'can': 89,
#  'most': 90,
#  'into': 91,
#  'york': 92,
#  'may': 93,
#  'over': 94,
#  'co.': 95,
#  'group': 96,
#  'many': 97,
#  'government': 98,
#  'now': 99,
#  'federal': 100,
#  'companies': 101,
#  'no': 102,
#  'time': 103,
#  'bank': 104,
#  'so': 105,
#  'any': 106,
#  'cents': 107,
#  'people': 108,
#  'quarter': 109,
#  'you': 110,
#  'exchange': 111,
#  'prices': 112,
#  'even': 113,
#  'what': 114,
#  'price': 115,
#  'investors': 116,
#  'say': 117,
#  'down': 118,
#  'rose': 119,
#  'while': 120,
#  'much': 121,
#  'yesterday': 122,
#  'week': 123,
#  'under': 124,
#  'securities': 125,
#  'months': 126,
#  'them': 127,
#  'bonds': 128,
#  'big': 129,
#  'next': 130,
#  'interest': 131,
#  'three': 132,
#  'earlier': 133,
#  "'": 134,
#  'net': 135,
#  'earnings': 136,
#  'major': 137,
#  'make': 138,
#  'state': 139,
#  'american': 140,
#  'chairman': 141,
#  'financial': 142,
#  'did': 143,
#  'these': 144,
#  'investment': 145,
#  'board': 146,
#  'still': 147,
#  'through': 148,
#  'stocks': 149,
#  'those': 150,
#  'chief': 151,
#  'just': 152,
#  'industry': 153,
#  'executive': 154,
#  'since': 155,
#  'program': 156,
#  'before': 157,
#  'rate': 158,
#  'made': 159,
#  'officials': 160,
#  'money': 161,
#  'national': 162,
#  'she': 163,
#  'analysts': 164,
#  'house': 165,
#  'like': 166,
#  'unit': 167,
#  'month': 168,
#  'expected': 169,
#  'off': 170,
#  'days': 171,
#  'rates': 172,
#  'japanese': 173,
#  'against': 174,
#  'does': 175,
#  'plan': 176,
#  'profit': 177,
#  'between': 178,
#  'both': 179,
#  'capital': 180,
#  'recent': 181,
#  'buy': 182,
#  'income': 183,
#  'sell': 184,
#  'issue': 185,
#  'revenue': 186,
#  'general': 187,
#  'get': 188,
#  'products': 189,
#  'markets': 190,
#  'firm': 191,
#  'back': 192,
#  'funds': 193,
#  'own': 194,
#  'ago': 195,
#  'average': 196,
#  'international': 197,
#  'during': 198,
#  'her': 199,
#  'well': 200,
#  'part': 201,
#  'fell': 202,
#  'japan': 203,
#  'another': 204,
#  'should': 205,
#  'higher': 206,
#  'debt': 207,
#  'offer': 208,
#  'take': 209,
#  'including': 210,
#  'among': 211,
#  'court': 212,
#  'being': 213,
#  'according': 214,
#  'each': 215,
#  'index': 216,
#  'tax': 217,
#  'trade': 218,
#  'world': 219,
#  'reported': 220,
#  'work': 221,
#  'operations': 222,
#  'then': 223,
#  'computer': 224,
#  'past': 225,
#  'sale': 226,
#  'however': 227,
#  'our': 228,
#  'way': 229,
#  'lower': 230,
#  'plans': 231,
#  'vice': 232,
#  'economic': 233,
#  'department': 234,
#  'end': 235,
#  'yield': 236,
#  'report': 237,
#  'sold': 238,
#  'insurance': 239,
#  'growth': 240,
#  'high': 241,
#  'how': 242,
#  'foreign': 243,
#  'increase': 244,
#  'less': 245,
#  'common': 246,
#  'banks': 247,
#  'closed': 248,
#  'several': 249,
#  'issues': 250,
#  'where': 251,
#  'loss': 252,
#  'very': 253,
#  'pay': 254,
#  'yen': 255,
#  'bush': 256,
#  'bid': 257,
#  'five': 258,
#  'due': 259,
#  'bill': 260,
#  'few': 261,
#  'good': 262,
#  'used': 263,
#  'current': 264,
#  'management': 265,
#  'early': 266,
#  'cash': 267,
#  'oil': 268,
#  'use': 269,
#  'costs': 270,
#  'bond': 271,
#  'day': 272,
#  'public': 273,
#  'system': 274,
#  "'re": 275,
#  'director': 276,
#  'third': 277,
#  'law': 278,
#  'might': 279,
#  'traders': 280,
#  'treasury': 281,
#  'friday': 282,
#  'added': 283,
#  'office': 284,
#  'city': 285,
#  'congress': 286,
#  'concern': 287,
#  'futures': 288,
#  'far': 289,
#  'officer': 290,
#  'late': 291,
#  'already': 292,
#  'fund': 293,
#  'assets': 294,
#  'california': 295,
#  'least': 296,
#  'number': 297,
#  'operating': 298,
#  'him': 299,
#  'small': 300,
#  'spokesman': 301,
#  'agency': 302,
#  'british': 303,
#  'based': 304,
#  'san': 305,
#  'too': 306,
#  'case': 307,
#  'real': 308,
#  'news': 309,
#  'value': 310,
#  'september': 311,
#  'same': 312,
#  'oct.': 313,
#  'until': 314,
#  'contract': 315,
#  'think': 316,
#  'close': 317,
#  'home': 318,
#  'research': 319,
#  'stake': 320,
#  'street': 321,
#  'union': 322,
#  'services': 323,
#  'going': 324,
#  'today': 325,
#  'little': 326,
#  'ended': 327,
#  'though': 328,
#  'move': 329,
#  'wall': 330,
#  'agreement': 331,
#  'dollar': 332,
#  'help': 333,
#  'second': 334,
#  'put': 335,
#  'service': 336,
#  'former': 337,
#  'power': 338,
#  'maker': 339,
#  'called': 340,
#  'period': 341,
#  'results': 342,
#  'administration': 343,
#  'agreed': 344,
#  'total': 345,
#  'four': 346,
#  'here': 347,
#  'third-quarter': 348,
#  'without': 349,
#  'control': 350,
#  'long': 351,
#  'corporate': 352,
#  'credit': 353,
#  'economy': 354,
#  'problems': 355,
#  'offering': 356,
#  'country': 357,
#  'want': 358,
#  'production': 359,
#  'buying': 360,
#  'cost': 361,
#  'loans': 362,
#  'six': 363,
#  'analyst': 364,
#  'firms': 365,
#  'although': 366,
#  'annual': 367,
#  'increased': 368,
#  'whether': 369,
#  'compared': 370,
#  'likely': 371,
#  'committee': 372,
#  'notes': 373,
#  'point': 374,
#  'policy': 375,
#  'recently': 376,
#  'cut': 377,
#  'see': 378,
#  'west': 379,
#  'large': 380,
#  'monday': 381,
#  'right': 382,
#  'soviet': 383,
#  'around': 384,
#  'continue': 385,
#  'go': 386,
#  'half': 387,
#  'set': 388,
#  'political': 389,
#  'life': 390,
#  'further': 391,
#  'losses': 392,
#  'old': 393,
#  'points': 394,
#  'volume': 395,
#  'yet': 396,
#  'august': 397,
#  'paper': 398,
#  'selling': 399,
#  'john': 400,
#  'judge': 401,
#  'plant': 402,
#  'must': 403,
#  'strong': 404,
#  'expects': 405,
#  'my': 406,
#  'nov.': 407,
#  'ual': 408,
#  'london': 409,
#  'result': 410,
#  'announced': 411,
#  'declined': 412,
#  'largest': 413,
#  'support': 414,
#  'fiscal': 415,
#  'held': 416,
#  'systems': 417,
#  'wo': 418,
#  'francisco': 419,
#  'takeover': 420,
#  'times': 421,
#  'weeks': 422,
#  'making': 423,
#  'priced': 424,
#  'certain': 425,
#  'earthquake': 426,
#  'become': 427,
#  'change': 428,
#  'composite': 429,
#  'gain': 430,
#  'workers': 431,
#  'businesses': 432,
#  'come': 433,
#  'problem': 434,
#  'south': 435,
#  'demand': 436,
#  'give': 437,
#  'industrial': 438,
#  'record': 439,
#  'nearly': 440,
#  'association': 441,
#  'development': 442,
#  'inc': 443,
#  'senior': 444,
#  'series': 445,
#  'white': 446,
#  'dow': 447,
#  'area': 448,
#  'members': 449,
#  'air': 450,
#  'data': 451,
#  'estimated': 452,
#  'took': 453,
#  'official': 454,
#  'orders': 455,
#  'employees': 456,
#  'trust': 457,
#  'estate': 458,
#  'jones': 459,
#  'decline': 460,
#  'level': 461,
#  'line': 462,
#  'senate': 463,
#  'show': 464,
#  'health': 465,
#  'later': 466,
#  'latest': 467,
#  'acquisition': 468,
#  'comment': 469,
#  'drop': 470,
#  'example': 471,
#  'junk': 472,
#  'commission': 473,
#  'meeting': 474,
#  'tuesday': 475,
#  'commercial': 476,
#  'ford': 477,
#  'holding': 478,
#  'know': 479,
#  'need': 480,
#  'building': 481,
#  'chicago': 482,
#  'texas': 483,
#  'your': 484,
#  'despite': 485,
#  'ms.': 486,
#  'addition': 487,
#  'currently': 488,
#  'paid': 489,
#  'proposal': 490,
#  'executives': 491,
#  'offered': 492,
#  'others': 493,
#  'possible': 494,
#  'deal': 495,
#  'once': 496,
#  'proposed': 497,
#  'purchase': 498,
#  'rise': 499,
#  'better': 500,
#  'loan': 501,
#  'return': 502,
#  'technology': 503,
#  'investor': 504,
#  'us': 505,
#  'future': 506,
#  'nation': 507,
#  'spending': 508,
#  'drug': 509,
#  'nine': 510,
#  'almost': 511,
#  'changes': 512,
#  'robert': 513,
#  'washington': 514,
#  'damage': 515,
#  'often': 516,
#  'received': 517,
#  'east': 518,
#  'product': 519,
#  'terms': 520,
#  'named': 521,
#  'october': 522,
#  'expect': 523,
#  'top': 524,
#  'charge': 525,
#  'customers': 526,
#  'filed': 527,
#  'decision': 528,
#  'information': 529,
#  'order': 530,
#  'within': 531,
#  'position': 532,
#  'defense': 533,
#  'force': 534,
#  'include': 535,
#  'rights': 536,
#  'division': 537,
#  'every': 538,
#  'gas': 539,
#  'america': 540,
#  'amount': 541,
#  'began': 542,
#  'enough': 543,
#  'came': 544,
#  'europe': 545,
#  'outstanding': 546,
#  'trying': 547,
#  'equipment': 548,
#  'private': 549,
#  'told': 550,
#  'found': 551,
#  'gains': 552,
#  'industries': 553,
#  'again': 554,
#  'ltd.': 555,
#  'dropped': 556,
#  'james': 557,
#  'makes': 558,
#  'previous': 559,
#  'programs': 560,
#  'united': 561,
#  'ca': 562,
#  'computers': 563,
#  'fed': 564,
#  'july': 565,
#  'transaction': 566,
#  'banking': 567,
#  'budget': 568,
#  'european': 569,
#  'co': 570,
#  'finance': 571,
#  'following': 572,
#  "'ve": 573,
#  'jaguar': 574,
#  'local': 575,
#  'never': 576,
#  'provide': 577,
#  'warner': 578,
#  'additional': 579,
#  'consumer': 580,
#  'lot': 581,
#  'mortgage': 582,
#  'able': 583,
#  'corp': 584,
#  'keep': 585,
#  'managers': 586,
#  'action': 587,
#  'buy-out': 588,
#  'important': 589,
#  'shareholders': 590,
#  'great': 591,
#  'charges': 592,
#  'claims': 593,
#  'got': 594,
#  'instead': 595,
#  'university': 596,
#  'away': 597,
#  'best': 598,
#  'car': 599,
#  'states': 600,
#  'steel': 601,
#  'units': 602,
#  'dollars': 603,
#  'financing': 604,
#  'tokyo': 605,
#  'construction': 606,
#  'things': 607,
#  'continued': 608,
#  'manager': 609,
#  'marketing': 610,
#  'run': 611,
#  'asked': 612,
#  'bills': 613,
#  'auto': 614,
#  'low': 615,
#  'fall': 616,
#  'family': 617,
#  'inflation': 618,
#  'march': 619,
#  'believe': 620,
#  'equity': 621,
#  'food': 622,
#  'june': 623,
#  'whose': 624,
#  'above': 625,
#  'advertising': 626,
#  'sept.': 627,
#  'below': 628,
#  'personal': 629,
#  'raise': 630,
#  'account': 631,
#  'full': 632,
#  'getting': 633,
#  'lost': 634,
#  'posted': 635,
#  'suit': 636,
#  'china': 637,
#  'head': 638,
#  'los': 639,
#  'soon': 640,
#  'taken': 641,
#  'rather': 642,
#  'stores': 643,
#  'contracts': 644,
#  'risk': 645,
#  'via': 646,
#  'included': 647,
#  'potential': 648,
#  'security': 649,
#  'western': 650,
#  'boston': 651,
#  'figures': 652,
#  'legal': 653,
#  'options': 654,
#  'restructuring': 655,
#  'special': 656,
#  'gold': 657,
#  'led': 658,
#  'mrs.': 659,
#  'reports': 660,
#  'subsidiary': 661,
#  'tv': 662,
#  'face': 663,
#  'noted': 664,
#  'place': 665,
#  'using': 666,
#  'dealers': 667,
#  'fact': 668,
#  'meanwhile': 669,
#  'open': 670,
#  'working': 671,
#  'countries': 672,
#  'd.': 673,
#  'holders': 674,
#  'network': 675,
#  'effort': 676,
#  'find': 677,
#  'approved': 678,
#  'available': 679,
#  'bought': 680,
#  'cases': 681,
#  'itself': 682,
#  'portfolio': 683,
#  'probably': 684,
#  'statement': 685,
#  '#': 686,
#  'effect': 687,
#  'ibm': 688,
#  'lawyers': 689,
#  'long-term': 690,
#  'pacific': 691,
#  'david': 692,
#  'short': 693,
#  'ad': 694,
#  'increases': 695,
#  'left': 696,
#  'reached': 697,
#  'airlines': 698,
#  'cars': 699,
#  'efforts': 700,
#  'labor': 701,
#  'along': 702,
#  'dividend': 703,
#  'domestic': 704,
#  'either': 705,
#  'germany': 706,
#  'remain': 707,
#  'known': 708,
#  'similar': 709,
#  'hard': 710,
#  'talks': 711,
#  'look': 712,
#  'reduce': 713,
#  'calls': 714,
#  'center': 715,
#  'chemical': 716,
#  'groups': 717,
#  'having': 718,
#  'previously': 719,
#  'reserve': 720,
#  'saying': 721,
#  'school': 722,
#  'secretary': 723,
#  'approval': 724,
#  'canada': 725,
#  'clear': 726,
#  'gained': 727,
#  'given': 728,
#  'parent': 729,
#  'party': 730,
#  'payments': 731,
#  'telephone': 732,
#  'eastern': 733,
#  'individual': 734,
#  'looking': 735,
#  'manufacturing': 736,
#  'north': 737,
#  'profits': 738,
#  'standard': 739,
#  'biggest': 740,
#  'canadian': 741,
#  'acquired': 742,
#  'helped': 743,
#  'investments': 744,
#  'savings': 745,
#  'slightly': 746,
#  'angeles': 747,
#  'directors': 748,
#  'raised': 749,
#  'strategy': 750,
#  'attorney': 751,
#  'black': 752,
#  'machines': 753,
#  'marks': 754,
#  'act': 755,
#  'bay': 756,
#  'coming': 757,
#  'institute': 758,
#  'military': 759,
#  'percentage': 760,
#  'television': 761,
#  'why': 762,
#  'airline': 763,
#  'clients': 764,
#  'makers': 765,
#  'medical': 766,
#  'performance': 767,
#  'britain': 768,
#  'different': 769,
#  'energy': 770,
#  'german': 771,
#  'heavy': 772,
#  'team': 773,
#  'growing': 774,
#  'hit': 775,
#  'interests': 776,
#  'communications': 777,
#  'estimates': 778,
#  'failed': 779,
#  'lead': 780,
#  'magazine': 781,
#  'particularly': 782,
#  'remains': 783,
#  'something': 784,
#  'william': 785,
#  'call': 786,
#  'completed': 787,
#  'fees': 788,
#  'job': 789,
#  'levels': 790,
#  'limited': 791,
#  'went': 792,
#  'hong': 793,
#  'includes': 794,
#  'joint': 795,
#  'michael': 796,
#  'process': 797,
#  'question': 798,
#  'role': 799,
#  'year-earlier': 800,
#  'activity': 801,
#  'district': 802,
#  'goods': 803,
#  'legislation': 804,
#  'lines': 805,
#  'project': 806,
#  'view': 807,
#  'columbia': 808,
#  'free': 809,
#  'leading': 810,
#  'me': 811,
#  'merrill': 812,
#  'property': 813,
#  'toward': 814,
#  'leaders': 815,
#  'name': 816,
#  'seeking': 817,
#  'venture': 818,
#  'currency': 819,
#  'deficit': 820,
#  'ever': 821,
#  'institutions': 822,
#  'rep.': 823,
#  'reserves': 824,
#  'wants': 825,
#  "'m": 826,
#  'concerns': 827,
#  'huge': 828,
#  'independent': 829,
#  'involved': 830,
#  'lynch': 831,
#  'owns': 832,
#  's&p': 833,
#  'scheduled': 834,
#  'taking': 835,
#  'turn': 836,
#  'build': 837,
#  'buyers': 838,
#  'doing': 839,
#  'gm': 840,
#  'hold': 841,
#  'kong': 842,
#  'outside': 843,
#  'pressure': 844,
#  'really': 845,
#  'transportation': 846,
#  'vote': 847,
#  'young': 848,
#  'always': 849,
#  'april': 850,
#  'basis': 851,
#  'begin': 852,
#  'calif.': 853,
#  'measure': 854,
#  'producers': 855,
#  'brokerage': 856,
#  'care': 857,
#  'daily': 858,
#  'especially': 859,
#  'leader': 860,
#  'staff': 861,
#  'key': 862,
#  'means': 863,
#  'plants': 864,
#  'related': 865,
#  'acquire': 866,
#  'adds': 867,
#  'aid': 868,
#  'competition': 869,
#  'disclosed': 870,
#  'projects': 871,
#  'richard': 872,
#  'themselves': 873,
#  'areas': 874,
#  'campaign': 875,
#  'central': 876,
#  'conference': 877,
#  'drexel': 878,
#  'impact': 879,
#  'range': 880,
#  'reason': 881,
#  'try': 882,
#  'abortion': 883,
#  'bad': 884,
#  'estimate': 885,
#  'holdings': 886,
#  'hours': 887,
#  'j.': 888,
#  'largely': 889,
#  'poor': 890,
#  'significant': 891,
#  'started': 892,
#  'allow': 893,
#  'french': 894,
#  'issued': 895,
#  'man': 896,
#  'meet': 897,
#  'reduced': 898,
#  'seems': 899,
#  'start': 900,
#  'test': 901,
#  'thing': 902,
#  'accounts': 903,
#  'course': 904,
#  'majority': 905,
#  'morgan': 906,
#  'retail': 907,
#  'rules': 908,
#  'congressional': 909,
#  'fourth': 910,
#  'needed': 911,
#  'press': 912,
#  'quickly': 913,
#  'seven': 914,
#  'wednesday': 915,
#  'journal': 916,
#  'longer': 917,
#  'partners': 918,
#  'seen': 919,
#  'settlement': 920,
#  "'ll": 921,
#  'community': 922,
#  'december': 923,
#  'done': 924,
#  'generally': 925,
#  'traded': 926,
#  'yields': 927,
#  'consider': 928,
#  'dec.': 929,
#  'manufacturers': 930,
#  'supply': 931,
#  'volatility': 932,
#  'beginning': 933,
#  'electric': 934,
#  'parts': 935,
#  'receive': 936,
#  'shearson': 937,
#  'study': 938,
#  'thursday': 939,
#  'women': 940,
#  'a.': 941,
#  'form': 942,
#  'imports': 943,
#  'kind': 944,
#  'men': 945,
#  'simply': 946,
#  'situation': 947,
#  'thought': 948,
#  'brokers': 949,
#  'convertible': 950,
#  'eight': 951,
#  'near': 952,
#  'note': 953,
#  'planned': 954,
#  'plc': 955,
#  'prime': 956,
#  'protection': 957,
#  'taxes': 958,
#  'turned': 959,
#  'auction': 960,
#  'boost': 961,
#  'democratic': 962,
#  'filing': 963,
#  'history': 964,
#  'recession': 965,
#  'short-term': 966,
#  'subject': 967,
#  'ahead': 968,
#  'changed': 969,
#  'rally': 970,
#  'required': 971,
#  'sen.': 972,
#  'space': 973,
#  'stock-index': 974,
#  'arbitrage': 975,
#  'base': 976,
#  'became': 977,
#  'dr.': 978,
#  'perhaps': 979,
#  'produce': 980,
#  'returns': 981,
#  'seek': 982,
#  'summer': 983,
#  'war': 984,
#  'worth': 985,
#  'advanced': 986,
#  'benefits': 987,
#  'caused': 988,
#  'considered': 989,
#  'de': 990,
#  'increasing': 991,
#  'moody': 992,
#  'motor': 993,
#  'showed': 994,
#  'software': 995,
#  'anything': 996,
#  'brothers': 997,
#  'creditors': 998,
#  'delivery': 999,
#  ...}

# %% [markdown]
# ### Demo for Recurrent Neural Network

# %% [markdown]
# <img src="rnn_pic.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# From the above figure you can observe that at RNN cell (left) is just a single neural network that is connected to itself. The unfolded representation is on right. It implies, at each time step the architecutre will not just recieve the current input but also the previous output. Therefore, the prediction at any time step depends on current input and all the previous inputs. This give the RNN the capability to learn a sequence.

# %%
model = language_model(data,update_rule='SGD_with_momentum',cell_type = 'rnn',batch_size = 128,seq_len= 2,epochs=70)
params = model.train()
# Out:
# Epoch 1/70
#     Iteration 1/78, Loss: 18.42156245411719
#     Iteration 51/78, Loss: 18.083903846302604
#     tr_acc: 0.11227964743589744, val_acc: 0.1099582248263889
# Epoch 2/70
#     Iteration 1/78, Loss: 17.63596647057056
#     Iteration 51/78, Loss: 16.16621535051767
#     tr_acc: 0.10426682692307693, val_acc: 0.103759765625
# Epoch 3/70
#     Iteration 1/78, Loss: 15.323147337155284
#     Iteration 51/78, Loss: 15.070407677346093
#     tr_acc: 0.12469951923076923, val_acc: 0.12406412760416667
# Epoch 4/70
#     Iteration 1/78, Loss: 14.574902949914055
#     Iteration 51/78, Loss: 14.681055789789589
#     tr_acc: 0.12690304487179488, val_acc: 0.1250949435763889
# Epoch 5/70
#     Iteration 1/78, Loss: 14.228969680960729
#     Iteration 51/78, Loss: 14.385314279447261
#     tr_acc: 0.15224358974358973, val_acc: 0.15059407552083334
# Epoch 6/70
#     Iteration 1/78, Loss: 13.971150764251302
#     Iteration 51/78, Loss: 14.123401840180534
#     tr_acc: 0.16005608974358973, val_acc: 0.1593967013888889
# Epoch 7/70
#     Iteration 1/78, Loss: 13.763714446663958
#     Iteration 51/78, Loss: 13.901898258826435
#     tr_acc: 0.16506410256410256, val_acc: 0.1650661892361111
# Epoch 8/70
#     Iteration 1/78, Loss: 13.596902610922008
#     Iteration 51/78, Loss: 13.711865360329089
#     tr_acc: 0.16606570512820512, val_acc: 0.1661105685763889
# Epoch 9/70
#     Iteration 1/78, Loss: 13.458016724932335
#     Iteration 51/78, Loss: 13.546460433551136
#     tr_acc: 0.1697716346153846, val_acc: 0.16807725694444445
# Epoch 10/70
#     Iteration 1/78, Loss: 13.340648298314067
#     Iteration 51/78, Loss: 13.402437198534884
#     tr_acc: 0.17678285256410256, val_acc: 0.17142740885416666
# Epoch 11/70
#     Iteration 1/78, Loss: 13.2406927973745
#     Iteration 51/78, Loss: 13.277193215168026
#     tr_acc: 0.1828926282051282, val_acc: 0.1725124782986111
# Epoch 12/70
#     Iteration 1/78, Loss: 13.153536791747772
#     Iteration 51/78, Loss: 13.16734623765999
#     tr_acc: 0.19801682692307693, val_acc: 0.17887369791666666
# Epoch 13/70
#     Iteration 1/78, Loss: 13.075469759237215
#     Iteration 51/78, Loss: 13.069616856627828
#     tr_acc: 0.22345753205128205, val_acc: 0.1936577690972222
# Epoch 14/70
#     Iteration 1/78, Loss: 13.004437581313663
#     Iteration 51/78, Loss: 12.981464190025559
#     tr_acc: 0.2361778846153846, val_acc: 0.2072482638888889
# Epoch 15/70
#     Iteration 1/78, Loss: 12.939123824599449
#     Iteration 51/78, Loss: 12.900931746218848
#     tr_acc: 0.23327323717948717, val_acc: 0.2110324435763889
# Epoch 16/70
#     Iteration 1/78, Loss: 12.87838402323132
#     Iteration 51/78, Loss: 12.826443707387451
#     tr_acc: 0.23247195512820512, val_acc: 0.21256510416666666
# Epoch 17/70
#     Iteration 1/78, Loss: 12.821154575264757
#     Iteration 51/78, Loss: 12.75671145939523
#     tr_acc: 0.23297275641025642, val_acc: 0.2134467230902778
# Epoch 18/70
#     Iteration 1/78, Loss: 12.766476210138874
#     Iteration 51/78, Loss: 12.690705560348368
#     tr_acc: 0.23357371794871795, val_acc: 0.2137993706597222
# Epoch 19/70
#     Iteration 1/78, Loss: 12.713511474766655
#     Iteration 51/78, Loss: 12.62764026343103
#     tr_acc: 0.23477564102564102, val_acc: 0.2141791449652778
# Epoch 20/70
#     Iteration 1/78, Loss: 12.661552566268337
#     Iteration 51/78, Loss: 12.566936708663363
#     tr_acc: 0.23627804487179488, val_acc: 0.2139350043402778
# Epoch 21/70
#     Iteration 1/78, Loss: 12.610024403403916
#     Iteration 51/78, Loss: 12.508165325675307
#     tr_acc: 0.23868189102564102, val_acc: 0.21385362413194445
# Epoch 22/70
#     Iteration 1/78, Loss: 12.558477234310063
#     Iteration 51/78, Loss: 12.450988946915029
#     tr_acc: 0.24208733974358973, val_acc: 0.21485731336805555
# Epoch 23/70
#     Iteration 1/78, Loss: 12.506570795000616
#     Iteration 51/78, Loss: 12.395121501127818
#     tr_acc: 0.2476963141025641, val_acc: 0.21687825520833334
# Epoch 24/70
#     Iteration 1/78, Loss: 12.454063059703305
#     Iteration 51/78, Loss: 12.340305267188388
#     tr_acc: 0.25400641025641024, val_acc: 0.2188178168402778
# Epoch 25/70
#     Iteration 1/78, Loss: 12.400812650980846
#     Iteration 51/78, Loss: 12.286304314146498
#     tr_acc: 0.25841346153846156, val_acc: 0.2193332248263889
# Epoch 26/70
#     Iteration 1/78, Loss: 12.346791287334707
#     Iteration 51/78, Loss: 12.232907748275974
#     tr_acc: 0.2649238782051282, val_acc: 0.2202690972222222
# Epoch 27/70
#     Iteration 1/78, Loss: 12.292090528620392
#     Iteration 51/78, Loss: 12.179935147295815
#     tr_acc: 0.2682291666666667, val_acc: 0.22117784288194445
# Epoch 28/70
#     Iteration 1/78, Loss: 12.236900820179088
#     Iteration 51/78, Loss: 12.127246481399776
#     tr_acc: 0.27353766025641024, val_acc: 0.22144911024305555
# Epoch 29/70
#     Iteration 1/78, Loss: 12.181454910069963
#     Iteration 51/78, Loss: 12.074772842227881
#     tr_acc: 0.2757411858974359, val_acc: 0.22395833333333334
# Epoch 30/70
#     Iteration 1/78, Loss: 12.125961206726632
#     Iteration 51/78, Loss: 12.022551166164039
#     tr_acc: 0.27714342948717946, val_acc: 0.2232394748263889
# Epoch 31/70
#     Iteration 1/78, Loss: 12.070563597023018
#     Iteration 51/78, Loss: 11.970696931343456
#     tr_acc: 0.28145032051282054, val_acc: 0.2239990234375
# Epoch 32/70
#     Iteration 1/78, Loss: 12.015360395115238
#     Iteration 51/78, Loss: 11.919348196672857
#     tr_acc: 0.28756009615384615, val_acc: 0.22713216145833334
# Epoch 33/70
#     Iteration 1/78, Loss: 11.96047577865154
#     Iteration 51/78, Loss: 11.868645271523466
#     tr_acc: 0.2936698717948718, val_acc: 0.2284884982638889
# Epoch 34/70
#     Iteration 1/78, Loss: 11.906092303034205
#     Iteration 51/78, Loss: 11.818719282231395
#     tr_acc: 0.2952724358974359, val_acc: 0.229248046875
# Epoch 35/70
#     Iteration 1/78, Loss: 11.85241388719201
#     Iteration 51/78, Loss: 11.769675177596138
#     tr_acc: 0.2988782051282051, val_acc: 0.22862413194444445
# Epoch 36/70
#     Iteration 1/78, Loss: 11.799610980380564
#     Iteration 51/78, Loss: 11.721578848605256
#     tr_acc: 0.30188301282051283, val_acc: 0.2289767795138889
# Epoch 37/70
#     Iteration 1/78, Loss: 11.747785865458368
#     Iteration 51/78, Loss: 11.674453173078373
#     tr_acc: 0.30649038461538464, val_acc: 0.2296413845486111
# Epoch 38/70
#     Iteration 1/78, Loss: 11.69696743060536
#     Iteration 51/78, Loss: 11.628280993332606
#     tr_acc: 0.31270032051282054, val_acc: 0.2296142578125
# Epoch 39/70
#     Iteration 1/78, Loss: 11.647129685764334
#     Iteration 51/78, Loss: 11.583011283958157
#     tr_acc: 0.31810897435897434, val_acc: 0.2294379340277778
# Epoch 40/70
#     Iteration 1/78, Loss: 11.598219290947679
#     Iteration 51/78, Loss: 11.538566092585818
#     tr_acc: 0.32572115384615385, val_acc: 0.23136393229166666
# Epoch 41/70
#     Iteration 1/78, Loss: 11.550176324216281
#     Iteration 51/78, Loss: 11.494847707780387
#     tr_acc: 0.328525641025641, val_acc: 0.23079427083333334
# Epoch 42/70
#     Iteration 1/78, Loss: 11.502942478063096
#     Iteration 51/78, Loss: 11.451746541426456
#     tr_acc: 0.33253205128205127, val_acc: 0.22896321614583334
# Epoch 43/70
#     Iteration 1/78, Loss: 11.456461666511327
#     Iteration 51/78, Loss: 11.409150093719997
#     tr_acc: 0.33613782051282054, val_acc: 0.22725423177083334
# Epoch 44/70
#     Iteration 1/78, Loss: 11.410679873398596
#     Iteration 51/78, Loss: 11.366952304612651
#     tr_acc: 0.33934294871794873, val_acc: 0.2262505425347222
# Epoch 45/70
#     Iteration 1/78, Loss: 11.3655468421737
#     Iteration 51/78, Loss: 11.325061435665214
#     tr_acc: 0.34134615384615385, val_acc: 0.22465006510416666
# Epoch 46/70
#     Iteration 1/78, Loss: 11.321018538288786
#     Iteration 51/78, Loss: 11.283404466072925
#     tr_acc: 0.34395032051282054, val_acc: 0.2240668402777778
# Epoch 47/70
#     Iteration 1/78, Loss: 11.277058536975336
#     Iteration 51/78, Loss: 11.241927156436706
#     tr_acc: 0.3490584935897436, val_acc: 0.22526041666666666
# Epoch 48/70
#     Iteration 1/78, Loss: 11.233637553923788
#     Iteration 51/78, Loss: 11.20059065726702
#     tr_acc: 0.3518629807692308, val_acc: 0.2249213324652778
# Epoch 49/70
#     Iteration 1/78, Loss: 11.190731583162695
#     Iteration 51/78, Loss: 11.159366637531747
#     tr_acc: 0.3563701923076923, val_acc: 0.2252197265625
# Epoch 50/70
#     Iteration 1/78, Loss: 11.148319610599241
#     Iteration 51/78, Loss: 11.118232786754156
#     tr_acc: 0.3602764423076923, val_acc: 0.225341796875
# Epoch 51/70
#     Iteration 1/78, Loss: 11.106381628715383
#     Iteration 51/78, Loss: 11.077169569587177
#     tr_acc: 0.3659855769230769, val_acc: 0.22557237413194445
# Epoch 52/70
#     Iteration 1/78, Loss: 11.064897197143768
#     Iteration 51/78, Loss: 11.036158159237992
#     tr_acc: 0.3698918269230769, val_acc: 0.226318359375
# Epoch 53/70
#     Iteration 1/78, Loss: 11.023844557345104
#     Iteration 51/78, Loss: 10.995179142091828
#     tr_acc: 0.3733974358974359, val_acc: 0.22682020399305555
# Epoch 54/70
#     Iteration 1/78, Loss: 10.983200412695187
#     Iteration 51/78, Loss: 10.954211818056425
#     tr_acc: 0.37740384615384615, val_acc: 0.2265625
# Epoch 55/70
#     Iteration 1/78, Loss: 10.942940637600321
#     Iteration 51/78, Loss: 10.913234338827184
#     tr_acc: 0.38231169871794873, val_acc: 0.2265082465277778
# Epoch 56/70
#     Iteration 1/78, Loss: 10.903042030898016
#     Iteration 51/78, Loss: 10.87222532445513
#     tr_acc: 0.3847155448717949, val_acc: 0.2260470920138889
# Epoch 57/70
#     Iteration 1/78, Loss: 10.863484734973103
#     Iteration 51/78, Loss: 10.831167940508754
#     tr_acc: 0.3899238782051282, val_acc: 0.2277153862847222
# Epoch 58/70
#     Iteration 1/78, Loss: 10.824254434567699
#     Iteration 51/78, Loss: 10.790057268860206
#     tr_acc: 0.39463141025641024, val_acc: 0.2279052734375
# Epoch 59/70
#     Iteration 1/78, Loss: 10.785343392007341
#     Iteration 51/78, Loss: 10.74890998261328
#     tr_acc: 0.3977363782051282, val_acc: 0.2279324001736111
# Epoch 60/70
#     Iteration 1/78, Loss: 10.746750117928876
#     Iteration 51/78, Loss: 10.707771135817616
#     tr_acc: 0.40184294871794873, val_acc: 0.22823079427083334
# Epoch 61/70
#     Iteration 1/78, Loss: 10.70847901675163
#     Iteration 51/78, Loss: 10.666709505727857
#     tr_acc: 0.40675080128205127, val_acc: 0.2282986111111111
# Epoch 62/70
#     Iteration 1/78, Loss: 10.670542506202317
#     Iteration 51/78, Loss: 10.625798104594802
#     tr_acc: 0.4117588141025641, val_acc: 0.2283935546875
# Epoch 63/70
#     Iteration 1/78, Loss: 10.632966295655457
#     Iteration 51/78, Loss: 10.585090746063118
#     tr_acc: 0.41746794871794873, val_acc: 0.2281222873263889
# Epoch 64/70
#     Iteration 1/78, Loss: 10.595793804713024
#     Iteration 51/78, Loss: 10.544611900606775
#     tr_acc: 0.42337740384615385, val_acc: 0.2285698784722222
# Epoch 65/70
#     Iteration 1/78, Loss: 10.559084222597232
#     Iteration 51/78, Loss: 10.504364045297708
#     tr_acc: 0.4296875, val_acc: 0.22865125868055555
# Epoch 66/70
#     Iteration 1/78, Loss: 10.522903727135404
#     Iteration 51/78, Loss: 10.464341493997132
#     tr_acc: 0.43309294871794873, val_acc: 0.22852918836805555
# Epoch 67/70
#     Iteration 1/78, Loss: 10.487314559140987
#     Iteration 51/78, Loss: 10.424539948978282
#     tr_acc: 0.43810096153846156, val_acc: 0.22847493489583334
# Epoch 68/70
#     Iteration 1/78, Loss: 10.452366650820512
#     Iteration 51/78, Loss: 10.384960067102966
#     tr_acc: 0.4424078525641026, val_acc: 0.2285427517361111
# Epoch 69/70
#     Iteration 1/78, Loss: 10.41809355263608
#     Iteration 51/78, Loss: 10.345609112693175
#     tr_acc: 0.44641426282051283, val_acc: 0.2280951605902778
# Epoch 70/70
#     Iteration 1/78, Loss: 10.384511958164046
#     Iteration 51/78, Loss: 10.306505371190724
#     tr_acc: 0.45322516025641024, val_acc: 0.22892252604166666

# %% [markdown]
# ### Do some predictions

# %%
# predict n next words
n = 3
model = language_model(data,cell_type = 'rnn',batch_size = 1,seq_len= n,use_pre_trained=True,params=params)
k = np.random.choice(5000, 1)[0] #random point
some_data = _divide_into_batches(train_data[k:k+100],1)
pred_str = []
for i in range(10):
    x,_=_get_batch(some_data,i,n)
    scores,_ = model.forward_pass(x)
    predictions = np.argmax(scores, axis = 2)
    #print(predictions)
    print('-'*80)
    print('actual sequnce    : '+str([ids_words[i] for i in x[0]]))
    print('predicted sequence: '+str([ids_words[i] for i in predictions[0]]))
# Out:
# --------------------------------------------------------------------------------
# actual sequnce    : ['the', '<unk>', 'was']
# predicted sequence: ['<unk>', '<unk>', 'to']
# --------------------------------------------------------------------------------
# actual sequnce    : ['<unk>', 'was', 'used']
# predicted sequence: ['<unk>', 'to', 'to']
# --------------------------------------------------------------------------------
# actual sequnce    : ['was', 'used', '<eos>']
# predicted sequence: ['to', 'to', '<unk>']
# --------------------------------------------------------------------------------
# actual sequnce    : ['used', '<eos>', 'workers']
# predicted sequence: ['to', 'the', 'and']
# --------------------------------------------------------------------------------
# actual sequnce    : ['<eos>', 'workers', 'dumped']
# predicted sequence: ['the', "'s", 'said']
# --------------------------------------------------------------------------------
# actual sequnce    : ['workers', 'dumped', 'large']
# predicted sequence: ['in', '<unk>', '<unk>']
# --------------------------------------------------------------------------------
# actual sequnce    : ['dumped', 'large', '<unk>']
# predicted sequence: ['<unk>', '<unk>', '<unk>']
# --------------------------------------------------------------------------------
# actual sequnce    : ['large', '<unk>', '<unk>']
# predicted sequence: ['<unk>', '<unk>', '<unk>']
# --------------------------------------------------------------------------------
# actual sequnce    : ['<unk>', '<unk>', 'of']
# predicted sequence: ['<unk>', '<unk>', 'the']
# --------------------------------------------------------------------------------
# actual sequnce    : ['<unk>', 'of', 'the']
# predicted sequence: ['<unk>', 'the', '<unk>']

# %% [markdown]
# The predictions do not make any sense as we trained the model for only one epoch on a fraction of data.

# %% [markdown]
# ### Implementation of Long Short Term Memory

# %% [markdown]
# The problem with RNN is that it is not suitable for learning long sequences. This inability is due to either vanishing gradient or exploding gradient. Fig below shows the examples of both.
#
# In case of vanishing gradient, when the sequence is long, the gradinent reduces at each step eventually becoming 0 (no more learning!).
#
# In case of exploding gradient, when the sequence is long, the gradient increases at each step eventually making the architecture unstable.
#
# To avoid both the scenarios, LSTM models were designed. The LSTM models use gates to decide which of the previous steps should participate in the current step prediction.
#
# The LSTM cell is shown below:

# %% [markdown]
# <img src="lstm_pic.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# Complete the following functions in rnn_layers.py to implement LSTM architecture
#
# 1. lstm_forward
# 2. lstm_step_forward
# 3. lstm_backward
# 4. lstm_step_backward

# %% [markdown]
# Run the below code after implementing the functions

# %%
model = language_model(data,update_rule='SGD_with_momentum',cell_type = 'lstm',batch_size = 128)
params = model.train()
# Out:
# Epoch 1/70
#     Iteration 1/78, Loss: 36.84074221531089
#     Iteration 51/78, Loss: 34.84889413533025
#     tr_acc: 0.21834935897435898, val_acc: 0.2225884331597222
# Epoch 2/70
#     Iteration 1/78, Loss: 32.2199586028576
#     Iteration 51/78, Loss: 30.409138597655648
#     tr_acc: 0.2244591346153846, val_acc: 0.2256401909722222
# Epoch 3/70
#     Iteration 1/78, Loss: 29.496922483596283
#     Iteration 51/78, Loss: 29.21081591057568
#     tr_acc: 0.20412660256410256, val_acc: 0.20518663194444445
# Epoch 4/70
#     Iteration 1/78, Loss: 28.418808081939623
