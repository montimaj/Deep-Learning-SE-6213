# %% [markdown]
# For this, the ‘relu’ activation function was used instead of the ‘softmax’ function. All other hyperparameters were unchanged. Accordingly, the model accuracies are significantly worse with the validation and test accuracies being 0.0995 and 0.0980 respectively. This is because for the MNIST dataset we are trying to predict the handwritten digits based on probabilities. Since ‘relu’ generates values in the [0,∞) interval, hence, using it as the output layer will fail to produce accurate results. Therefore, the ‘softmax’ function which generates values in the (0,1) interval must be used as the output layer of our model.

# %%
import tensorflow as tf
import numpy as np
from  tensorflow import keras

# %%
# choosing a random seed for reproducibility
np.random.seed(0)

# %%
# network and training 
EPOCHS = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 #number of outputs =  Number of digits
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # How much data is reserved for validation

# %%
# loading MNIST dataset
# verify the split between train and test is 60,000 and 10,000 respectively one -hot is automatically applied
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], ' test samples')
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000  test samples

# %%
RESHAPED=784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
#normalize in [0,1]
X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
#one-hot
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

# %%
#build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(NB_CLASSES,
   		input_shape=(RESHAPED,),
   		name='dense_layer', 
   		activation='relu'))

# summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_layer (Dense)          (None, 10)                7850
# ...
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the model
model.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training the model
model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3869 - val_loss: nan - val_accuracy: 0.0995
# Epoch 2/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 3/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 4/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 5/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 6/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# Epoch 7/200
# 375/375 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.0985 - val_loss: nan - val_accuracy: 0.0995
# ...

# %%
#evaluate the model
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

# making prediction
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 0s 812us/step - loss: 0.2776 - accuracy: 0.9223
# Test accuracy: 0.9222999811172485
